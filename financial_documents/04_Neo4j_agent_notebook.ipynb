# %% [markdown]
# # Neo4j + LLM Conversational Agent Notebook
#
# This notebook demonstrates a conversational agent that:
# - Uses LangChain, OpenAI, and Neo4j to answer questions about company risk factors.
# - Tracks each conversation session and every message in Neo4j.
# - Logs which company and risk factor nodes were involved in each answer.
# - Maintains message order: Each message in a session is linked to the next message via a `:NEXT` relationship, allowing you to traverse the conversation in order.
#
# **Data Model:**
# - `Session` nodes represent a user's chat session.
# - `Message` nodes represent each question/answer pair.
# - Relationships:
#     - `(:Session)-[:HAS_MESSAGE]->(:Message)` links sessions to messages.
#     - `(:Message)-[:NEXT]->(:Message)` links each message to the next in the session.
#     - `(:Message)-[:INVOLVES_COMPANY]->(:Company)` and `(:Message)-[:INVOLVES_RISK]->(:RiskFactor)` track which nodes were referenced in the answer.
#
# ---

# %%
# %pip install langchain-openai
# %pip install langchain-core
# %pip install langchain-neo4j
# %pip install langgraph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (0.3.28)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.68 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.3.69)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (1.97.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (4.14.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (9.1.2)
# Requirement already satisfied: packaging>=23.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (25.0)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.68->langchain-openai) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (3.11.0)
# Requirement already satisfied: requests<3,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.32.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.28.1)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.23.0)
# Requirement already satisfied: idna in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (3.10)
# Requirement already satisfied: anyio in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.0.9)
# Requirement already satisfied: certifi in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (2025.7.14)
# Requirement already satisfied: h11>=0.16 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.16.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: tqdm>4 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: sniffio in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.3.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.33.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (3.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-core in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (0.3.69)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: packaging>=23.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core) (25.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core) (4.14.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core) (2.11.7)
# Requirement already satisfied: PyYAML>=5.3 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: requests<3,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core) (2.32.4)
# Requirement already satisfied: anyio in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (4.9.0)
# Requirement already satisfied: idna in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (3.10)
# Requirement already satisfied: httpcore==1.* in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: certifi in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (2025.7.14)
# Requirement already satisfied: h11>=0.16 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core) (0.4.1)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core) (3.4.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.3.1)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-neo4j
#   Downloading langchain_neo4j-0.4.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: neo4j-graphrag<2.0.0,>=1.5.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-neo4j) (1.7.0)
# Requirement already satisfied: neo4j<6.0.0,>=5.25.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-neo4j) (5.28.1)
# Requirement already satisfied: langchain<0.4.0,>=0.3.7 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-neo4j) (0.3.26)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.8 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-neo4j) (0.3.69)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.4.6)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.0.41)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.11.7)
# Requirement already satisfied: requests<3,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.32.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (1.33)
# Requirement already satisfied: packaging>=23.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (25.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.28.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (3.11.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.23.0)
# Requirement already satisfied: anyio in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.0.9)
# Requirement already satisfied: idna in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (3.10)
# Requirement already satisfied: certifi in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (2025.7.14)
# Requirement already satisfied: h11>=0.16 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.16.0)
# Requirement already satisfied: pytz in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from neo4j<6.0.0,>=5.25.0->langchain-neo4j) (2025.2)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (5.8.0)
# Requirement already satisfied: json-repair<0.40.0,>=0.39.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (0.39.1)
# Requirement already satisfied: fsspec<2025.0.0,>=2024.9.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (2024.12.0)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (6.0.12.20250516)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.3.1)
# Installing collected packages: langchain-neo4j
# Successfully installed langchain-neo4j-0.4.0
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langgraph
#   Downloading langgraph-0.5.4-py3-none-any.whl (143 kB)
#      |████████████████████████████████| 143 kB 1.6 MB/s eta 0:00:01
# Collecting langgraph-prebuilt<0.6.0,>=0.5.0
#   Downloading langgraph_prebuilt-0.5.2-py3-none-any.whl (23 kB)
# Collecting xxhash>=3.5.0
#   Downloading xxhash-3.5.0-cp39-cp39-macosx_11_0_arm64.whl (30 kB)
# Requirement already satisfied: langchain-core>=0.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langgraph) (0.3.69)
# Collecting langgraph-sdk<0.2.0,>=0.1.42
#   Downloading langgraph_sdk-0.1.74-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: pydantic>=2.7.4 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langgraph) (2.11.7)
# Collecting langgraph-checkpoint<3.0.0,>=2.1.0
#   Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=23.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core>=0.1->langgraph) (4.14.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langchain-core>=0.1->langgraph) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Collecting ormsgpack>=1.10.0
#   Downloading ormsgpack-1.10.0-cp39-cp39-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (376 kB)
#      |████████████████████████████████| 376 kB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: httpx>=0.25.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.11.0)
# Requirement already satisfied: anyio in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: certifi in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (2025.7.14)
# Requirement already satisfied: h11>=0.16 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.16.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests<3,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.32.4)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (3.4.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)
# Installing collected packages: ormsgpack, langgraph-checkpoint, xxhash, langgraph-sdk, langgraph-prebuilt, langgraph
# Successfully installed langgraph-0.5.4 langgraph-checkpoint-2.1.1 langgraph-prebuilt-0.5.2 langgraph-sdk-0.1.74 ormsgpack-1.10.0 xxhash-3.5.0
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Environment and Dependency Setup
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI
from langgraph.prebuilt import create_react_agent
from langchain_core.tools import Tool
from langchain import hub
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_neo4j import Neo4jChatMessageHistory, Neo4jGraph
from uuid import uuid4
from pprint import pprint
# Out:
# /Users/ameymahajanmehta/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## Configuration
# Make sure your `.env` file contains your Neo4j and OpenAI credentials:
#
# ```
# NEO4J_URI=neo4j+s://<your-instance>.databases.neo4j.io
# NEO4J_USERNAME=your_username
# NEO4J_PASSWORD=your_password
# OPENAI_API_KEY=your_openai_key
# ```

# %%
NEO4J_URI = "neo4j+s://0e39a427.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "5qAQp_sJS3DoW98Mx0X41PN91yKPqEtCzMagYYY3cdQ"
AURA_INSTANCEID="0e39a427"
SESSION_ID = str(uuid4())

# --- Azure OpenAI config ---
API_KEY = "CJf0VBRpakDXgiWW8wxUT7hL9CbaOmE979tyuEGMg0J5n5zsnWOOJQQJ99BGACYeBjFXJ3w3AAABACOGRVVR"
API_ENDPOINT = "https://ameytxtai.openai.azure.com/"
API_VERSION = "2023-12-01-preview"
DEPLOYMENT_NAME_LLM = "test_jpm_3_5"
DEPLOYMENT_NAME_EMBED = "text-embedding01"


llm = AzureChatOpenAI(
    deployment_name=DEPLOYMENT_NAME_LLM,
    openai_api_key=API_KEY,
    azure_endpoint=API_ENDPOINT,
    openai_api_version=API_VERSION,
    temperature=0
)
graph = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USER,
    password=NEO4J_PASSWORD,
    database=AURA_INSTANCEID,
)
print(f'Session ID: {SESSION_ID}')
# Out:
# ---------------------------------------------------------------------------
# GqlError                                  Traceback (most recent call last)
# GqlError: {gql_status: 22N51} {gql_status_description: error: data exception - graph reference not found. A graph reference with the name `0e39a427` was not found. Verify that the spelling is correct.} {message: 22N51: A graph reference with the name `0e39a427` was not found. Verify that the spelling is correct.} {diagnostic_record: {'_classification': 'CLIENT_ERROR', 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}} {raw_classification: CLIENT_ERROR}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# Cell In[2], line 22
#      12 DEPLOYMENT_NAME_EMBED = "text-embedding01"
#      15 llm = AzureChatOpenAI(
#      16     deployment_name=DEPLOYMENT_NAME_LLM,
#      17     openai_api_key=API_KEY,
#    (...)
#      20     temperature=0
#      21 )
# ---> 22 graph = Neo4jGraph(
#      23     url=NEO4J_URI,
#      24     username=NEO4J_USER,
#      25     password=NEO4J_PASSWORD,
#      26     database=AURA_INSTANCEID,
#      27 )
#      28 print(f'Session ID: {SESSION_ID}')
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_neo4j/graphs/neo4j_graph.py:180, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     174 if e.code == "Neo.ClientError.Procedure.ProcedureNotFound":
#     175     raise ValueError(
#     176         "Could not use APOC procedures. "
#     177         "Please ensure the APOC plugin is installed in Neo4j and that "
#     178         "'apoc.meta.data()' is allowed in Neo4j configuration "
#     179     )
# --> 180 raise e
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_neo4j/graphs/neo4j_graph.py:172, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     170 if refresh_schema:
#     171     try:
# --> 172         self.refresh_schema()
#     173     except neo4j.exceptions.ClientError as e:
#     174         if e.code == "Neo.ClientError.Procedure.ProcedureNotFound":
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_neo4j/graphs/neo4j_graph.py:278, in Neo4jGraph.refresh_schema(self)
#     271 """
#     272 Refreshes the Neo4j graph schema information.
#     273
#     274 Raises:
#     275     RuntimeError: If the connection has been closed.
#     276 """
#     277 self._check_driver_state()
# --> 278 self.structured_schema = get_structured_schema(
#     279     driver=self._driver,
#     280     is_enhanced=self._enhanced_schema,
#     281     database=self._database,
#     282     timeout=self.timeout,
#     283     sanitize=self.sanitize,
#     284 )
#     285 self.schema = format_schema(
#     286     schema=self.structured_schema, is_enhanced=self._enhanced_schema
#     287 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j_graphrag/schema.py:289, in get_structured_schema(driver, is_enhanced, database, timeout, sanitize)
#     228 def get_structured_schema(
#     229     driver: neo4j.Driver,
#     230     is_enhanced: bool = False,
#    (...)
#     233     sanitize: bool = False,
#     234 ) -> dict[str, Any]:
#     235     """
#     236     Returns the structured schema of the graph.
#     237
#    (...)
#     285         dict[str, Any]: the graph schema information in a structured format.
#     286     """
#     287     node_properties = [
#     288         data["output"]
# --> 289         for data in query_database(
#     290             driver=driver,
#     291             query=NODE_PROPERTIES_QUERY,
#     292             params={
#     293                 "EXCLUDED_LABELS": EXCLUDED_LABELS
#     294                 + [BASE_ENTITY_LABEL, BASE_KG_BUILDER_LABEL]
#     295             },
#     296             database=database,
#     297             timeout=timeout,
#     298             sanitize=sanitize,
#     299         )
#     300     ]
#     302     rel_properties = [
#     303         data["output"]
#     304         for data in query_database(
#    (...)
#     311         )
#     312     ]
#     314     relationships = [
#     315         data["output"]
#     316         for data in query_database(
#    (...)
#     326         )
#     327     ]
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j_graphrag/schema.py:164, in query_database(driver, query, params, session_params, database, timeout, sanitize)
#     143 """
#     144 Queries the database.
#     145
#    (...)
#     161     list[dict[str, Any]]: the result of the query in json format.
#     162 """
#     163 if not session_params:
# --> 164     data = driver.execute_query(
#     165         Query(text=query, timeout=timeout),
#     166         database_=database,
#     167         parameters_=params,
#     168     )
#     169     json_data = [r.data() for r in data.records]
#     170     if sanitize:
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/driver.py:970, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     966     raise ValueError(
#     967         f"Invalid routing control value: {routing_!r}"
#     968     )
#     969 with session._pipelined_begin:
# --> 970     return session._run_transaction(
#     971         access_mode,
#     972         TelemetryAPI.DRIVER,
#     973         work,
#     974         (query_str, parameters, result_transformer_),
#     975         {},
#     976     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/work/session.py:572, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     570 while True:
#     571     try:
# --> 572         self._open_transaction(
#     573             tx_cls=ManagedTransaction,
#     574             api=None if telemetry_sent else api,
#     575             access_mode=access_mode,
#     576             metadata=metadata,
#     577             timeout=timeout,
#     578             api_success_cb=api_success_cb,
#     579         )
#     580         assert isinstance(self._transaction, ManagedTransaction)
#     581         tx = self._transaction
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/work/session.py:441, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     431 def _open_transaction(
#     432     self,
#     433     *,
#    (...)
#     439     api_success_cb: t.Callable[[dict], None] | None = None,
#     440 ) -> None:
# --> 441     self._connect(access_mode=access_mode)
#     442     assert self._connection is not None
#     443     if api is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/work/session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/work/workspace.py:199, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     189 acquire_kwargs_ = {
#     190     "access_mode": access_mode,
#     191     "timeout": acquisition_timeout,
#    (...)
#     196     "database_callback": self._make_db_resolution_callback(),
#     197 }
#     198 acquire_kwargs_.update(acquire_kwargs)
# --> 199 self._connection = self._pool.acquire(**acquire_kwargs_)
#     200 if (
#     201     target_db.guessed
#     202     and not self._pinned_database
#    (...)
#     206     # support SSR.
#     207     # => we need to fall back to explicit home database resolution
#     208     log.debug(
#     209         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     210         "falling back to explicit home database resolution",
#     211     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_pool.py:1161, in Neo4jPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, database_callback)
#    1153     Util.callback(database_callback, new_database)
#    1155 log.debug(
#    1156     "[#0000]  _: <POOL> acquire routing connection, "
#    1157     "access_mode=%r, database=%r",
#    1158     access_mode,
#    1159     database,
#    1160 )
# -> 1161 self.ensure_routing_table_is_fresh(
#    1162     access_mode=access_mode,
#    1163     database=database,
#    1164     imp_user=None,
#    1165     bookmarks=bookmarks,
#    1166     auth=auth,
#    1167     acquisition_timeout=timeout,
#    1168     database_callback=(
#    1169         wrapped_database_callback
#    1170         if database.guessed
#    1171         else database_callback
#    1172     ),
#    1173 )
#    1175 while True:
#    1176     try:
#    1177         # Get an address for a connection that have the fewest in-use
#    1178         # connections.
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_pool.py:1084, in Neo4jPool.ensure_routing_table_is_fresh(self, access_mode, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#    1081     Util.callback(database_callback, database)
#    1082     self.update_connection_pool()
# -> 1084 self.update_routing_table(
#    1085     database=database_request,
#    1086     imp_user=imp_user,
#    1087     bookmarks=bookmarks,
#    1088     auth=auth,
#    1089     acquisition_timeout=acquisition_timeout,
#    1090     database_callback=wrapped_database_callback,
#    1091 )
#    1093 return True
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_pool.py:971, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     964     existing_routers = {self.address}
#     965     prefer_initial_routing_address = True
#     967 if (
#     968     prefer_initial_routing_address
#     969     and
#     970     # TODO: Test this state
# --> 971     self._update_routing_table_from(
#     972         self.address,
#     973         database=database,
#     974         imp_user=imp_user,
#     975         bookmarks=bookmarks,
#     976         auth=auth,
#     977         acquisition_timeout=acquisition_timeout,
#     978         database_callback=database_callback,
#     979     )
#     980 ):
#     981     # Why is only the first initial routing address used?
#     982     return
#     983 if self._update_routing_table_from(
#     984     *(existing_routers - {self.address}),
#     985     database=database,
#    (...)
#     990     database_callback=database_callback,
#     991 ):
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_pool.py:902, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     898 for router in routers:
#     899     for address in NetworkUtil.resolve_address(
#     900         router, resolver=self.pool_config.resolver
#     901     ):
# --> 902         new_routing_table = self.fetch_routing_table(
#     903             address=address,
#     904             acquisition_timeout=acquisition_timeout,
#     905             database=database,
#     906             imp_user=imp_user,
#     907             bookmarks=bookmarks,
#     908             auth=auth,
#     909         )
#     910         if new_routing_table is not None:
#     911             new_database = new_routing_table.database
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_pool.py:815, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth)
#     813 new_routing_info = None
#     814 try:
# --> 815     new_routing_info = self.fetch_routing_info(
#     816         address,
#     817         database,
#     818         imp_user,
#     819         bookmarks,
#     820         auth,
#     821         acquisition_timeout,
#     822     )
#     823 except Neo4jError as e:
#     824     # checks if the code is an error that is caused by the client. In
#     825     # this case there is no sense in trying to fetch a RT from another
#     826     # router. Hence, the driver should fail fast during discovery.
#     827     if e._is_fatal_during_discovery():
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_pool.py:778, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     776 cx = self._acquire(address, auth, deadline, None)
#     777 try:
# --> 778     routing_table = cx.route(
#     779         database=database or self.workspace_config.database,
#     780         imp_user=imp_user or self.workspace_config.impersonated_user,
#     781         bookmarks=bookmarks,
#     782     )
#     783 finally:
#     784     self.release(cx)
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_bolt5.py:237, in Bolt5x0.route(self, database, imp_user, bookmarks, dehydration_hooks, hydration_hooks)
#     228 self._append(
#     229     b"\x66",
#     230     (routing_context, bookmarks, db_context),
#    (...)
#     234     dehydration_hooks=dehydration_hooks,
#     235 )
#     236 self.send_all()
# --> 237 self.fetch_all()
#     238 return [metadata.get("rt")]
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_bolt.py:879, in Bolt.fetch_all(self)
#     877 response = self.responses[0]
#     878 while not response.complete:
# --> 879     detail_delta, summary_delta = self.fetch_message()
#     880     detail_count += detail_delta
#     881     summary_count += summary_delta
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File ~/Library/Python/3.9/lib/python/site-packages/neo4j/_sync/io/_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Database.DatabaseNotFound} {message: Unable to get a routing table for database '0e39a427' because this database does not exist}

# %% [markdown]
# ## Agent Prompt and Tool Definition
# The agent uses a prompt that restricts answers to only what is in the graph. The tool queries risk factors for a given company.

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert on SEC filings and company data. ALWAYS use the provided tools to answer questions. NEVER answer directly. If you don't know, say you don't know."),
    ("human", "{input}"),
])
last_query_nodes = {}
def company_query_tool(query: str) -> str:
    """
    Query Neo4j for risk factors associated with a company.
    Returns company name and a list of risk factor names and IDs.
    Also saves the involved node IDs for logging.
    """
    cypher = """
    MATCH (c:Company)-[:FACES_RISK]->(r:RiskFactor)
    WHERE toLower(c.name) CONTAINS toLower($query)
    RETURN elementId(c) AS company_id, c.name AS company_name, collect({id: elementId(r), text: r.name}) AS risks
    LIMIT 1
    """
    results = graph.query(cypher, params={"query": query})
    if results:
        company_id = results[0]['company_id']
        company_name = results[0]['company_name']
        risks = results[0]['risks']
        risk_lines = "\n".join([f"- {r['text']} (id: {r['id']})" for r in risks])
        global last_query_nodes
        last_query_nodes = {
            "company_id": company_id,
            "risk_ids": [r['id'] for r in risks]
        }
        return f"Company: {company_name} (id: {company_id})\nRisk Factors:\n{risk_lines}"
    last_query_nodes.clear()
    return "No matching company or risk factors found."

# %% [markdown]
# ## Logging: Store Session, Message, and Relationships
# Each message is stored as a node and linked to the session. Messages are chained in order by the `:NEXT` relationship.

# %%
def log_query_nodes_to_neo4j(session_id, question, answer, company_id, risk_ids):
    """
    Log the session, message, and involved nodes to Neo4j.
    Also chains messages in order via :NEXT relationship.
    """
    cypher = """
    MERGE (s:Session {id: $session_id})
    WITH s
    OPTIONAL MATCH (s)-[:HAS_MESSAGE]->(prev:Message)
    WITH s, prev
    ORDER BY prev.timestamp DESC
    LIMIT 1
    CREATE (m:Message {question: $question, answer: $answer, timestamp: datetime()})
    MERGE (s)-[:HAS_MESSAGE]->(m)
    FOREACH (_ IN CASE WHEN prev IS NOT NULL THEN [1] ELSE [] END |
        MERGE (prev)-[:NEXT]->(m)
    )
    WITH m
    MATCH (c) WHERE elementId(c) = $company_id
    MERGE (m)-[:INVOLVES_COMPANY]->(c)
    WITH m
    UNWIND $risk_ids AS rid
    MATCH (r) WHERE elementId(r) = rid
    MERGE (m)-[:INVOLVES_RISK]->(r)
    """
    graph.query(
        cypher,
        params={
            "session_id": session_id,
            "question": question,
            "answer": answer,
            "company_id": company_id,
            "risk_ids": risk_ids,
        }
    )

# %% [markdown]
# ## Agent, Tool, and Memory Setup: Detailed Explanation
#
# This section configures the conversational agent using LangChain, Neo4j, and OpenAI.
# Below is a breakdown of each component, its purpose, and links to official documentation or source code.
#
# - **Tool.from_function**
#   Registers a custom Python function as a tool the agent can use.
#   [Docs: Custom Tools](https://python.langchain.com/docs/modules/agents/tools/custom_tools/)
#
# - **tools**
#   A list of all tools available to the agent.
#   [Docs: Tools for Agents](https://python.langchain.com/docs/modules/agents/tools/)
#
# - **hub.pull("hwchase17/react-chat")**
#   Loads a high-quality, community prompt template for the ReAct agent from the [LangChain Hub](https://python.langchain.com/docs/hub/).
#   [Prompt Example](https://smith.langchain.com/hub/hwchase17/react-chat)
#
# - **create_react_agent**
#   Creates a ReAct-style agent that can use tools, reason, and answer questions.
#   [Docs: ReAct Agent](https://python.langchain.com/docs/modules/agents/agent_types/react/)
#
# - **AgentExecutor**
#   Wraps the agent and tools into an executable interface.
#   [Docs: AgentExecutor](https://python.langchain.com/docs/modules/agents/agent_executor/)
#
# - **Neo4jChatMessageHistory**
#   Provides persistent, session-based chat memory in Neo4j.
#   [Docs: Message History](https://python.langchain.com/docs/modules/memory/message_history/)
#
# - **RunnableWithMessageHistory**
#   Wraps the agent to provide context-aware responses using message history.
#   [Docs: RunnableWithMessageHistory](https://python.langchain.com/docs/modules/memory/message_history/)
#
# **Summary Table**
#
# | Component                      | Purpose/Role                                         | Docs/Source                                                                                      |
# |---------------------------------|-----------------------------------------------------|--------------------------------------------------------------------------------------------------|
# | Tool.from_function              | Register function as a tool for the agent           | [Docs](https://python.langchain.com/docs/modules/agents/tools/custom_tools/)                     |
# | tools                           | List of agent tools                                 | [Docs](https://python.langchain.com/docs/modules/agents/tools/)                                  |
# | hub.pull                        | Load community prompt template                      | [Docs](https://python.langchain.com/docs/hub/) [Prompt](https://smith.langchain.com/hub/hwchase17/react-chat) |
# | create_react_agent              | Create a ReAct agent                                | [Docs](https://python.langchain.com/docs/modules/agents/agent_types/react/)                      |
# | AgentExecutor                   | Run agent and tools                                 | [Docs](https://python.langchain.com/docs/modules/agents/agent_executor/)                         |
# | Neo4jChatMessageHistory         | Store/retrieve session chat history in Neo4j        | [Docs](https://python.langchain.com/docs/modules/memory/message_history/)                        |
# | RunnableWithMessageHistory      | Add memory to agent for context-aware responses     | [Docs](https://python.langchain.com/docs/modules/memory/message_history/)                        |

# %%
company_tool = Tool.from_function(
    name="Company Info",
    description="Query the graph for company risk factors or information. Input is a company name or question.",
    func=company_query_tool,
)
tools = [company_tool]
agent_prompt = hub.pull("hwchase17/react-chat")
agent = create_react_agent(model=llm, tools=tools, prompt=agent_prompt)

def get_memory(session_id):
    return Neo4jChatMessageHistory(session_id=session_id, graph=graph)

chat_agent = RunnableWithMessageHistory(
    agent,
    get_memory,
    input_messages_key="input",
    history_messages_key="chat_history",
)

# %% [markdown]
# ## Conversation Handling and Logging
#
# This section defines how user questions are sent to the agent, how responses are handled, and how the conversation is logged both in Python and in Neo4j.
#
# ### `conversation = []`
# - This is a Python list that stores the full history of the current session in-memory.
# - Each entry is a dictionary with `"question"` and `"response"` keys, preserving the order of interaction.
# - Useful for quickly reviewing the conversation in the notebook, independent of Neo4j.
#
# ### `def ask_agent(question):`
# This function is the main interface for interacting with the agent. Here’s what happens step-by-step:
#
# 1. **Send the Question to the Agent**
#     - Calls `chat_agent.invoke(...)` with the user’s question and the current session ID.
#     - The agent uses the full message history for context-aware responses.
#
# 2. **Capture the Answer**
#     - Extracts the agent’s answer from the response.
#
# 3. **Append to Local Conversation**
#     - Adds a dictionary with the question and response to the `conversation` list.
#     - This allows you to review the session in the notebook.
#
# 4. **Log to Neo4j**
#     - If `last_query_nodes` exists (i.e., the agent used the company tool and found relevant nodes), the function:
#         - Calls `log_query_nodes_to_neo4j` to:
#             - Store the session, message, and relationships (company, risk factors) in Neo4j.
#             - Chain messages in order via the `:NEXT` relationship.
#
# 5. **Print and Return the Answer**
#     - Prints the agent’s answer for immediate feedback in the notebook.
#     - Returns the answer so it can be used in further processing if needed.
#
# ---
#
# **Why is this design useful?**
# - **Session persistence:** All questions and answers are logged in Neo4j, so the full conversation (and the order of messages) can be reconstructed at any time.
# - **Node traceability:** Each message is linked to the specific company and risk factor nodes it referenced, enabling downstream graph analysis.
# - **Notebook review:** The `conversation` list allows you to see the session history without querying Neo4j.
# - **Reproducibility:** Every run is tracked and can be audited or replayed.
#
# **Example usage:**
# ```python
# ask_agent("What are the risk factors for Apple?")
# ask_agent("What about Microsoft?")
# print(conversation)

# %%
conversation = []
def ask_agent(question):
    """
    Ask the agent a question. Logs the message and involved nodes in Neo4j.
    Maintains message order within the session.
    """
    response = chat_agent.invoke(
        {"input": question},
        {"configurable": {"session_id": SESSION_ID}},
    )
    answer = response["output"]
    conversation.append({"question": question, "response": answer})
    if 'last_query_nodes' in globals() and last_query_nodes:
        log_query_nodes_to_neo4j(
            SESSION_ID,
            question,
            answer,
            last_query_nodes.get("company_id"),
            last_query_nodes.get("risk_ids", [])
        )
    pprint(answer)   
    return

# %% [markdown]
# ---
# **Usage:**
# - Use `ask_agent("your question")` to interact with the agent.
# - Each message is logged and chained in order for the session.
# - You can query Neo4j to reconstruct the full, ordered conversation for any session.

# %%
ask_agent("What are the risk factors associated with Apple?")

# %%
ask_agent("What are the risk factors associated with microsoft?")

# %%
ask_agent("What are the risk factors are shared by Microsoft and Apple?")

# %% [markdown]
# ## Analyzing Conversation Messages in Neo4j
#
# With every message logged in Neo4j (and chained by session), you can perform rich analyses, such as:
#
# - **Conversation statistics:** How many messages per session? What is the average/median message length?
# - **Most discussed companies:** Which companies are most frequently referenced?
# - **Risk factor trends:** Which risk factors are most often discussed?
# - **Session timelines:** How does conversation flow over time?
# - **Message chains:** How are messages ordered and connected?
#
# Below are some example analyses and queries you can use.
#
# The following code cells use the Neo4j Python driver (via the LangChain `Neo4jGraph` object `graph`) to run Cypher queries and analyze the conversation/message data.

# %%
# Count the number of messages in each session
cypher = """
MATCH (s:Session)-[:HAS_MESSAGE]->(m:Message)
RETURN s.id AS session_id, count(m) AS message_count
ORDER BY message_count DESC
"""
results = graph.query(cypher)
for row in results:
    print(f"Session {row['session_id']} has {row['message_count']} messages")

# %%
# Find the most mentioned companies across all messages
cypher = """
MATCH (m:Message)-[:INVOLVES_COMPANY]->(c:Company)
RETURN c.name AS company, count(m) AS mentions
ORDER BY mentions DESC
LIMIT 10
"""
results = graph.query(cypher)
print("Top 10 most mentioned companies:")
for row in results:
    print(f"{row['company']}: {row['mentions']} mentions")

# %%
# Find the most mentioned risk factors
cypher = """
MATCH (m:Message)-[:INVOLVES_RISK]->(r:RiskFactor)
RETURN r.name AS risk_factor, count(m) AS mentions
ORDER BY mentions DESC
LIMIT 10
"""
results = graph.query(cypher)
print("Top 10 most mentioned risk factors:")
for row in results:
    print(f"{row['risk_factor']}: {row['mentions']} mentions")
